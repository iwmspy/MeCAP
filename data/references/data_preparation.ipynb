# %% [markdown]
# # Data preparation for building Uni-Mea models

# %% [markdown]
# ## 0. Download and unzip
#
# This procedure is following [this reference](https://github.com/jensengroup/ESNUEL_ML).

# %%
# Download and check included files
# !wget -O data.tar.xz https://sid.erda.dk/share_redirect/c7LF5NaYvH; tar -tvf data.tar.xz | head
# Out:
# --2025-09-26 14:20:16--  https://sid.erda.dk/share_redirect/c7LF5NaYvH
# Resolving sid.erda.dk (sid.erda.dk)... 130.225.104.13
# Connecting to sid.erda.dk (sid.erda.dk)|130.225.104.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170060920 (1.1G)
# Saving to: ‘data.tar.xz’
#
# data.tar.xz         100%[===================>]   1.09G  1.79MB/s    in 7m 37s
#
# 2025-09-26 14:27:55 (2.44 MB/s) - ‘data.tar.xz’ saved [1170060920/1170060920]
#
# drwxr-xr-x nicolairee/staff  0 2024-08-15 19:36 data/
# drwxr-xr-x nicolairee/staff  0 2024-10-03 02:57 data/benchmark/
# -rw-r--r-- nicolairee/staff 120 2024-08-15 22:53 data/._.DS_Store
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# -rw-r--r-- nicolairee/staff 6148 2024-08-15 22:53 data/.DS_Store
# drwxr-xr-x nicolairee/staff    0 2024-08-16 21:57 data/uncertaintyEstimates/
# drwxr-xr-x nicolairee/staff    0 2024-08-15 20:58 data/QMdata4ML/
# drwxr-xr-x nicolairee/staff    0 2024-08-30 21:56 data/hydrolysis/
# -rw-r--r-- nicolairee/staff 3491 2024-08-30 21:06 data/hydrolysis/101016jjtice202106045_data.csv
# -rw-r--r-- nicolairee/staff 48529 2024-08-30 21:56 data/hydrolysis/CAEHydrolysisDataset.csv
# -rw-r--r-- nicolairee/staff 11270 2024-08-30 21:07 data/hydrolysis/public_hydrolysis_data_tebes_stevens.csv
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseLabels'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseConfidences'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseLabels'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseConfidences'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: stdout: write error

# %%
# Now unzip necessary data 'QMdata4ML' to current directory
# !tar --extract \
    --file=data.tar.xz \
    --xz \
    --strip-components=1 \
    --directory=. \
    data/QMdata4ML
# Out:
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseLabels'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseConfidences'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseLabels'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseConfidences'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemTextContentLanguage'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:kMDItemKeyphraseVersion'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'

# %% [markdown]
# ## 1. Reference split (from the paper written by [Ree et. al.](https://doi.org/10.1039/D4SC07297A))

# %% [markdown]
# Since our procedure requires dataset to make the column containing 'train', 'val' and 'test', the integrated split column will be divided to each fold by the following procedure.

# %%
# Trial
import pandas as pd
pd.read_csv('./QMdata4ML/df_elec_x.csv.gz',index_col=0,nrows=5)
# Out:
#            smiles  elec_sites   elec_names  MAA_values  \
# 0  NOCc1cccc(I)c1           3  double_bond   90.348433
# 1  NOCc1cccc(I)c1           4  double_bond   94.924314
# 2  NOCc1cccc(I)c1           5  double_bond   91.330269
# 3  NOCc1cccc(I)c1           6  double_bond  102.683928
# 4  NOCc1cccc(I)c1           7  double_bond  276.204538
#
#                                       elec_GCS_3_cm5          Set  \
# 0  [-0.01706, 0.12057, -0.11146, -0.08969, 0.0, -...  Train_fold5
# 1  [-0.08969, -0.01706, -0.08484, 0.09939, 0.0, 0...  Train_fold2
# 2  [-0.08484, -0.10499, -0.08969, 0.09122, 0.0, 0...  Train_fold3
# 3  [-0.10499, 0.01492, -0.08484, 0.08707, 0.0, 0....  Train_fold1
# 4  [0.01492, 0.00479, -0.11146, -0.10499, 0.0, 0....  Train_fold3
#
#                                   elec_SMI2GCS_3_cm5  \
# 0  [-0.00668, 0.12661, -0.09866, -0.09247, 0.0, -...
# 1  [-0.09247, -0.00668, -0.07901, 0.0887, 0.0, 0....
# 2  [-0.07901, -0.09933, -0.09247, 0.08588, 0.0, 0...
# 3  [-0.09933, 0.00749, -0.07901, 0.08466, 0.0, 0....
# 4  [0.00749, 0.01751, -0.09866, -0.09933, 0.0, 0....
#
#                                   elec_SMI2GCS_5_cm5  \
# 0  [-0.00668, 0.12661, -0.09866, -0.09247, 0.0, -...
# 1  [-0.09247, -0.00668, -0.07901, 0.0887, 0.0, 0....
# 2  [-0.07901, -0.09933, -0.09247, 0.08588, 0.0, 0...
# 3  [-0.09933, 0.00749, -0.07901, 0.08466, 0.0, 0....
# 4  [0.00749, 0.01751, -0.09866, -0.09933, 0.0, 0....
#
#                                elec_RDKitCountFP_512  \
# 0  [4, 0, 4, 5, 2, 3, 0, 4, 3, 6, 0, 6, 4, 1, 0, ...
# 1  [4, 0, 4, 7, 0, 1, 0, 4, 1, 6, 0, 4, 4, 1, 0, ...
# 2  [2, 0, 4, 7, 0, 3, 0, 4, 2, 3, 0, 5, 2, 0, 0, ...
# 3  [0, 0, 5, 6, 0, 3, 0, 4, 2, 1, 0, 7, 3, 0, 0, ...
# 4  [2, 0, 5, 6, 2, 3, 0, 4, 3, 2, 0, 6, 3, 0, 0, ...
#
#                             elec_RDKitGasteigerGCS_5  \
# 0  [-0.01928812973227673, 0.0929936027236162, -0....
# 1  [-0.056572952259338685, -0.01928812973227673, ...
# 2  [-0.060854479918004876, -0.04882194239545837, ...
# 3  [-0.04882194239545837, 0.013342809000888595, -...
# 4  [0.013342809000888595, -0.04430373540190993, -...
#
#                                    elec_AtomNumGCS_5
# 0  [6, 6, 6, 6, 0.0, 8, 1, 1, 6, 1, 0.0, 6, 1, 0....
# 1  [6, 6, 6, 1, 0.0, 6, 6, 0.0, 6, 1, 0.0, 0.0, 0...
# 2  [6, 6, 6, 1, 0.0, 6, 1, 0.0, 6, 1, 0.0, 0.0, 0...
# 3  [6, 6, 6, 1, 0.0, 53, 6, 0.0, 6, 1, 0.0, 0.0, ...
# 4  [6, 53, 6, 6, 0.0, 0.0, 0.0, 0.0, 6, 1, 0.0, 6...

# %%
# Make name col from original data
df_origin = pd.read_csv('./QMdata4ML/df_ChEMBL50K.csv.gz',index_col=0)

df_elec = pd.read_csv('./QMdata4ML/df_elec_x.csv.gz',index_col=0)
df_nuc  = pd.read_csv('./QMdata4ML/df_nuc_x.csv.gz',index_col=0)

# %%
smi_dict = {row['smiles']: row['name'] for idx, row in df_origin.iterrows()}

df_elec['name'] = df_elec['smiles'].map(smi_dict)
df_nuc['name'] = df_nuc['smiles'].map(smi_dict)

# %%
# Create indivisual 'Fold' columns
def convert_fold(name, fold_num=1):
    if 'train' in name.lower():
        if name.lower() == f'train_fold{fold_num}':
            return 'val'
        else:
            return 'train'
    else:
        return name.lower()

for fnum in range(1,6):
    df_elec[f'Set_fold{fnum}'] = df_elec['Set'].apply(lambda f: convert_fold(f,fnum))
    df_nuc[f'Set_fold{fnum}'] = df_nuc['Set'].apply(lambda f: convert_fold(f,fnum))

# %% [markdown]
# ## 2. Scaffold-based split
#
# Duplication of compounds is allowed in the reference split. However, the whole information of molecule is input in our model. Therefore, for the guarantee of extraporate, we built the model with Bemis-Murcko-scaffold-splitting.

# %%
# !~/miniconda3/envs/mecap/bin/python _ScaffoldSplit.py \
#     --input_csv ./QMdata4ML/df_ChEMBL50K.csv.gz \
#     --smiles_col smiles \
#     --out_split_csv ./split_sim.csv \
#     --out_scaffold_map_csv ./scaf_map.csv \
#     --out_scaffold_pairs_csv ./scaf_pairs.csv \
#     --n_workers 8

# %%
spl = pd.read_csv('split.csv',index_col=0)

sf = spl['fold'].to_dict()
scaf = spl['scaffold_max_sim_to_train'].to_dict()

df_elec['Set_scaffold'] = df_elec['smiles'].map(sf)
df_nuc['Set_scaffold'] = df_nuc['smiles'].map(sf)

df_nuc['ScafMaxSim'] = df_nuc['smiles'].map(scaf)
df_elec['ScafMaxSim'] = df_elec['smiles'].map(scaf)

# %%
from tqdm import tqdm
from _rdkitAtomWiseFP import site_feature_vector, add_md_parallel_tqdm

tqdm.pandas()

df_elec['rdkitAtomWiseFP'] = df_elec.progress_apply(lambda row: site_feature_vector(row['smiles'],row['elec_sites']), axis=1)
df_nuc['rdkitAtomWiseFP'] = df_nuc.progress_apply(lambda row: site_feature_vector(row['smiles'],row['nuc_sites']), axis=1)

df_elec['MDist'] = add_md_parallel_tqdm(df_elec, 'rdkitAtomWiseFP', 'Set_scaffold', n_workers=10)
df_nuc['MDist'] = add_md_parallel_tqdm(df_nuc, 'rdkitAtomWiseFP', 'Set_scaffold', n_workers=10)
# Out:
# 100%|██████████| 534119/534119 [01:47<00:00, 4952.54it/s]
# 100%|██████████| 650857/650857 [02:29<00:00, 4364.72it/s]
# Mahalanobis: 100%|██████████| 534119/534119 [00:02<00:00, 247790.13row/s]
# Mahalanobis: 100%|██████████| 650857/650857 [00:02<00:00, 277000.93row/s]

# %% [markdown]
# ## -1. Save split datas

# %%
df_elec.to_csv('./QMdata4ML/df_elec_x_with_name_fold.csv')
df_nuc.to_csv('./QMdata4ML/df_nuc_x_with_name_fold.csv')

# %% [markdown]
# Now you can run the training script!

# %% [markdown]
# # Obtain xTB-optimized conformers (optional, but required for conformational impact analysis)
#
# Retrieve source xTB-optimized conformers for QM-derived MCA/MAA.

# %%
# Download and check included files
# !wget -O calculations.tar.xz https://sid.erda.dk/share_redirect/hp3ttQcTgs; tar -tvf calculations.tar.xz | head

# %%
# !tar -tvf calculations.tar.xz > filelist.txt
# !tar --wildcards -xvf calculations.tar.xz '*/reac01/*/orca_calc.out'

# %%
plist = []
with open('./filelist.txt','r') as f:
    for p in f.readlines():
        if 'reac01/' in p and 'orca_calc' in p:
            plist.append(p)

# %%
plist[0].split()[-1].strip()
# Out:
# 'groups/kemi/ree/PhD/applications/ESNUEL/ChEMBL50K/calculations/41203004d8954391ed1c752531b37432/reac01/conf08/gfn1/orca_calc.out'

# %%
import os
from _ConvertOrcaToSDF import orca_out_to_sdf

os.makedirs('./confs_orca',exist_ok=True)
for path in plist:
    p = path.split()[-1].strip()
    orca_out_to_sdf(p,os.path.join('./confs_orca', p.split('/')[-5]+'.sdf'))

# %%
from rdkit import Chem

supp = Chem.SDMolSupplier('41203004d8954391ed1c752531b37432.sdf',removeHs=False)
supp[0]

# %% [markdown]
# # Sampling for Gaussian calculation

# %%
# # Trial
# import pandas as pd
# df_mol = pd.read_pickle('./QMdata4ML/ChEMBL50K_ESNUELresults.pkl')
# df_mlready = pd.read_pickle('./QMdata4ML/df_MLready.pkl')
# df_mol = df_mol[df_mol['name'].isin(df_mlready['name'].to_list())]

# %%
# import numpy as np

# fixed_properties = ['name','smiles']
# elec_properties  = ['elec_sites','elec_prod_smis','elec_names','MAA_values','MAA_calc_logs']
# nuc_properties   = ['nuc_sites','nuc_prod_smis','nuc_names','MCA_values','MCA_calc_logs']

# def parse_props(row):
#     props = {
#         'elec_props': elec_properties,
#         'nuc_props': nuc_properties
#     }
#     res_lists = {}

#     for prop_name, prop_list in props.items():
#         parsed = []
#         for ps in zip(*(row[idx][0] for idx in prop_list)):
#             if (ps[-1][0][0] == None and ps[-1][-1][0] == None and np.abs(ps[-2]) != np.inf):
#                 parsed.append({n: v for n, v in zip(prop_list, ps)})
#             elif np.abs(ps[-2]) == np.inf:
#                 continue
#         res_lists[prop_name] = parsed
    
#     return pd.Series(res_lists)

# df_mol_props = df_mol[fixed_properties].copy()
# df_mol_props[['elec_props','nuc_props']] = df_mol.apply(parse_props,axis=1)

# df_mol_props = df_mol_props[(df_mol_props['elec_props'].apply(lambda l: len(l) > 0)) & (df_mol_props['nuc_props'].apply(lambda l: len(l) > 0))]

# %%
# df_mol_props_sample_10000 = df_mol_props.sample(11000, random_state=42) # Buffer

# %%
# import random
# random.seed(42)

# def choose_one_sample(row):
#     return pd.Series({
#         'elec_choice': random.choice(row['elec_props']),
#         'nuc_choice': random.choice(row['nuc_props'])
#     })

# df_mol_props_sample_10000[['elec_choice','nuc_choice']] = df_mol_props_sample_10000.apply(choose_one_sample, axis=1)

# %%
# df_mol_props_sample_10000_trans = pd.concat([
#     df_mol_props_sample_10000[fixed_properties],
#     pd.DataFrame(df_mol_props_sample_10000['elec_choice'].to_list(),index=df_mol_props_sample_10000.index),
#     pd.DataFrame(df_mol_props_sample_10000['nuc_choice'].to_list(),index=df_mol_props_sample_10000.index)
#     ],axis=1)
# df_mol_props_sample_10000_trans.to_csv('./df_sample_10000.csv.gz',compression='gzip')
#
# df_mol_props_sample_10000_elec = pd.concat([
#     df_mol_props_sample_10000[fixed_properties],
#     pd.DataFrame(df_mol_props_sample_10000['elec_choice'].to_list(),index=df_mol_props_sample_10000.index),
#     ],axis=1)
# df_mol_props_sample_10000_elec['elec_prod_name'] = df_mol_props_sample_10000_elec.apply(lambda row: f'{row["name"]}_elec_{row["elec_sites"]}',axis=1)
# df_mol_props_sample_10000_elec.to_csv('./df_elec_sample_10000.csv.gz',compression='gzip')

# df_mol_props_sample_10000_nuc = pd.concat([
#     df_mol_props_sample_10000[fixed_properties],
#     pd.DataFrame(df_mol_props_sample_10000['nuc_choice'].to_list(),index=df_mol_props_sample_10000.index)
#     ],axis=1)
# df_mol_props_sample_10000_nuc['nuc_prod_name'] = df_mol_props_sample_10000_nuc.apply(lambda row: f'{row["name"]}_nuc_{row["nuc_sites"]}',axis=1)
# df_mol_props_sample_10000_nuc.to_csv('./df_nuc_sample_10000.csv.gz',compression='gzip')

# %%
# dfs = {
#     '_10000': df_mol_props_sample_10000,
#     }

# for key, df in dfs.items():
#     res_txt = ''
#     for idx, row in df.iterrows():
#         res_txt += f"groups/kemi/ree/PhD/applications/ESNUEL/ChEMBL50K/calculations/{row['elec_choice']['MAA_calc_logs'][0][-1].rsplit('/',1)[0]}/orca_calc.out\n"
#         res_txt += f"groups/kemi/ree/PhD/applications/ESNUEL/ChEMBL50K/calculations/{row['elec_choice']['MAA_calc_logs'][1][-1].rsplit('/',1)[0]}/orca_calc.out\n"
#         res_txt += f"groups/kemi/ree/PhD/applications/ESNUEL/ChEMBL50K/calculations/{row['nuc_choice']['MCA_calc_logs'][1][-1].rsplit('/',1)[0]}/orca_calc.out\n"
#     with open(f'./structure_file{key}.txt','w') as f:
#         f.write(res_txt)

# %%
# !tar -I 'xz -T0' --no-same-owner --no-same-permissions -xvf calculations.tar.xz -T structure_file_10000.txt

# %%
import ast
import os
import pandas as pd
from _ConvertOrcaToSDF import orca_out_to_sdf

os.makedirs('./confs_for_gaussian_input',exist_ok=True)
df_mol_props_sample_10000_trans = pd.read_csv('./df_sample_10000.csv.gz',index_col=0)

for idx, row in df_mol_props_sample_10000_trans.iterrows():
    p = f"groups/kemi/ree/PhD/applications/ESNUEL/ChEMBL50K/calculations/{ast.literal_eval(row['MAA_calc_logs'])[0][-1].rsplit('/',1)[0]}/orca_calc.out"
    orca_out_to_sdf(p,os.path.join('./confs_for_gaussian_input', p.split('/')[-5]+'.sdf'))
    for phil in ('elec','nuc'):
        pref = 'MAA' if 'elec' in phil else 'MCA'
        p = f"groups/kemi/ree/PhD/applications/ESNUEL/ChEMBL50K/calculations/{ast.literal_eval(row[f'{pref}_calc_logs'])[-1][-1].rsplit('/',1)[0]}/orca_calc.out"
        orca_out_to_sdf(p, os.path.join('./confs_for_gaussian_input', p.split('/')[-5] + '_' + phil + '_' + str(row[f'{phil}_sites']) + '.sdf'))

# %%
from glob import glob
import tarfile

path_all = glob('./confs_for_gaussian_input/*.sdf')

with tarfile.open('./sample_confs.tar.gz', 'w:gz') as tar:
    for file_path in path_all:
        tar.add(file_path, arcname=os.path.basename(file_path))

# %%
import os
from tqdm import tqdm
from glob import glob
from _ConvertOrcaToSDF import orca_out_to_sdf

out_dir = './confs_optimized_by_orca'
os.makedirs(out_dir, exist_ok=True)

path_all = glob('./gaussian_optimized/orca_summary_outputs/**/*.out', recursive=True)

for path in tqdm(path_all):
    orca_out_to_sdf(path, os.path.join(out_dir, path.split('/')[-2]+'.sdf'))
# Out:
# 100%|██████████| 32848/32848 [23:20<00:00, 23.45it/s]

# %%
!~/miniconda3/envs/mecap/bin/python ../../src/sanity_check_for_raw_data.py \
    --input-csv df_nuc_sample_10000.csv.gz \
    --input-dirs confs_optimized_by_orca \
    --out-csv df_sample_10000_sanity.csv \
    --smiles-col smiles \
    --name-col name \
    --level connectivity

!~/miniconda3/envs/mecap/bin/python ../../src/sanity_check_for_raw_data.py \
    --input-csv df_nuc_sample_10000.csv.gz \
    --input-dirs confs_optimized_by_orca \
    --out-csv df_nuc_sample_10000_sanity.csv \
    --smiles-col nuc_prod_smis \
    --name-col nuc_prod_name \
    --level connectivity

!~/miniconda3/envs/mecap/bin/python ../../src/sanity_check_for_raw_data.py \
    --input-csv df_elec_sample_10000.csv.gz \
    --input-dirs confs_optimized_by_orca \
    --out-csv df_elec_sample_10000_sanity.csv \
    --smiles-col elec_prod_smis \
    --name-col elec_prod_name \
    --level connectivity
# Out:
# [Info] xTB path: /home/iwasaki/miniconda3/envs/mecap/bin/xtb
# 100%|███████████████████████████████████| 11000/11000 [00:03<00:00, 2856.37it/s]
#   0%|                                                 | 0/11000 [00:00<?, ?it/s]!!! Warning !!! Distance between atoms 24 and 11 (0.968498 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 7 (0.967464 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 19 (0.966386 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 18 (0.974081 A) is suspicious.
#   0%|                                         | 4/11000 [00:00<05:08, 35.65it/s]!!! Warning !!! Distance between atoms 34 and 15 (0.967468 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 17 (0.968196 A) is suspicious.
#   0%|                                         | 9/11000 [00:00<04:22, 41.83it/s]!!! Warning !!! Distance between atoms 24 and 3 (0.973916 A) is suspicious.
#   0%|                                        | 23/11000 [00:00<04:36, 39.73it/s]!!! Warning !!! Distance between atoms 47 and 21 (0.973277 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 3 (0.975882 A) is suspicious.
#   0%|                                        | 33/11000 [00:00<04:21, 41.94it/s]!!! Warning !!! Distance between atoms 29 and 4 (0.966439 A) is suspicious.
# !!! Warning !!! Distance between atoms 24 and 8 (0.969788 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 14 (0.969651 A) is suspicious.
#   0%|▏                                       | 39/11000 [00:00<04:19, 42.21it/s]!!! Warning !!! Distance between atoms 18 and 3 (0.971956 A) is suspicious.
# !!! Warning !!! Distance between atoms 19 and 4 (0.971924 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 3 (0.974906 A) is suspicious.
#   0%|▏                                       | 44/11000 [00:01<04:23, 41.51it/s]!!! Warning !!! Distance between atoms 20 and 3 (0.974053 A) is suspicious.
#   0%|▏                                       | 49/11000 [00:01<04:36, 39.57it/s]!!! Warning !!! Distance between atoms 36 and 12 (0.968203 A) is suspicious.
#   0%|▏                                       | 53/11000 [00:01<04:44, 38.50it/s]!!! Warning !!! Distance between atoms 33 and 10 (0.968501 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 14 (0.970366 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 16 (0.968525 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 22 (0.968264 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 10 (0.969206 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 16 (0.969951 A) is suspicious.
#   1%|▏                                       | 58/11000 [00:01<04:32, 40.22it/s]!!! Warning !!! Distance between atoms 29 and 6 (0.969074 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 8 (0.969091 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 10 (0.974519 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 10 (0.966576 A) is suspicious.
#   1%|▏                                       | 63/11000 [00:01<04:40, 38.93it/s]!!! Warning !!! Distance between atoms 32 and 9 (0.966415 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 11 (0.968638 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 12 (0.968393 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 15 (0.968400 A) is suspicious.
#   1%|▎                                       | 71/11000 [00:01<05:00, 36.32it/s]!!! Warning !!! Distance between atoms 27 and 5 (0.966276 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 12 (0.979718 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 10 (0.969821 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 18 (0.966839 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 25 (0.969994 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 19 (0.974026 A) is suspicious.
#   1%|▎                                       | 76/11000 [00:01<04:34, 39.79it/s]!!! Warning !!! Distance between atoms 30 and 16 (0.974774 A) is suspicious.
#   1%|▎                                       | 85/11000 [00:02<05:09, 35.25it/s]!!! Warning !!! Distance between atoms 28 and 1 (0.966644 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 16 (0.981608 A) is suspicious.
#   1%|▎                                       | 89/11000 [00:02<05:18, 34.22it/s]!!! Warning !!! Distance between atoms 24 and 12 (0.972304 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 11 (0.974473 A) is suspicious.
#   1%|▎                                       | 95/11000 [00:02<04:31, 40.12it/s]!!! Warning !!! Distance between atoms 16 and 5 (0.973202 A) is suspicious.
# !!! Warning !!! Distance between atoms 22 and 11 (0.970125 A) is suspicious.
#   1%|▎                                      | 103/11000 [00:02<03:59, 45.47it/s]!!! Warning !!! Distance between atoms 42 and 15 (0.965563 A) is suspicious.
# !!! Warning !!! Distance between atoms 24 and 9 (0.971023 A) is suspicious.
#   1%|▍                                      | 108/11000 [00:02<04:13, 43.00it/s]!!! Warning !!! Distance between atoms 51 and 20 (0.973096 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 26 (0.967122 A) is suspicious.
#   1%|▍                                      | 113/11000 [00:02<04:31, 40.10it/s]!!! Warning !!! Distance between atoms 30 and 7 (0.971973 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 26 (0.966943 A) is suspicious.
#   1%|▍                                      | 124/11000 [00:03<05:02, 36.00it/s]!!! Warning !!! Distance between atoms 44 and 14 (0.968200 A) is suspicious.
#   1%|▍                                      | 130/11000 [00:03<04:31, 40.04it/s]!!! Warning !!! Distance between atoms 27 and 8 (0.969935 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 18 (0.970264 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 20 (0.972081 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 22 (0.967658 A) is suspicious.
#   1%|▍                                      | 135/11000 [00:03<04:28, 40.45it/s]!!! Warning !!! Distance between atoms 40 and 15 (0.967303 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 9 (0.966971 A) is suspicious.
#   1%|▌                                      | 145/11000 [00:03<04:31, 39.97it/s]!!! Warning !!! Distance between atoms 51 and 26 (0.965365 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 29 (0.974104 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 7 (0.971231 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 18 (0.971992 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 22 (0.967784 A) is suspicious.
#   1%|▌                                      | 150/11000 [00:03<04:37, 39.12it/s]!!! Warning !!! Distance between atoms 27 and 12 (0.970441 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 18 (0.968550 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 16 (0.968059 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 27 (0.978325 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 26 (0.968394 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 28 (0.969844 A) is suspicious.
#   1%|▌                                      | 163/11000 [00:04<04:43, 38.17it/s]!!! Warning !!! Distance between atoms 38 and 17 (0.968720 A) is suspicious.
#   2%|▌                                      | 169/11000 [00:04<04:20, 41.54it/s]!!! Warning !!! Distance between atoms 47 and 27 (0.997913 A) is suspicious.
#   2%|▌                                      | 174/11000 [00:04<04:10, 43.28it/s]!!! Warning !!! Distance between atoms 46 and 23 (0.974839 A) is suspicious.
#   2%|▋                                      | 179/11000 [00:04<04:50, 37.19it/s]!!! Warning !!! Distance between atoms 32 and 6 (0.973754 A) is suspicious.
#   2%|▋                                      | 183/11000 [00:04<04:55, 36.63it/s]!!! Warning !!! Distance between atoms 49 and 22 (0.967106 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 3 (0.973963 A) is suspicious.
#   2%|▋                                      | 188/11000 [00:04<04:49, 37.29it/s]!!! Warning !!! Distance between atoms 54 and 21 (0.968429 A) is suspicious.
# !!! Warning !!! Distance between atoms 55 and 23 (0.967924 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 18 (0.968591 A) is suspicious.
#   2%|▋                                      | 192/11000 [00:04<04:49, 37.28it/s]!!! Warning !!! Distance between atoms 35 and 19 (0.976993 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 17 (0.972174 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 18 (0.971251 A) is suspicious.
#   2%|▋                                      | 198/11000 [00:05<04:34, 39.32it/s]!!! Warning !!! Distance between atoms 42 and 14 (0.974155 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 3 (0.974320 A) is suspicious.
#   2%|▋                                      | 202/11000 [00:05<04:43, 38.05it/s]!!! Warning !!! Distance between atoms 17 and 1 (0.971942 A) is suspicious.
#   2%|▋                                      | 207/11000 [00:05<04:41, 38.35it/s]!!! Warning !!! Distance between atoms 50 and 17 (0.977214 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 18 (0.972702 A) is suspicious.
#   2%|▋                                      | 211/11000 [00:05<04:51, 37.07it/s]!!! Warning !!! Distance between atoms 35 and 18 (0.974802 A) is suspicious.
#   2%|▊                                      | 217/11000 [00:05<04:24, 40.77it/s]!!! Warning !!! Distance between atoms 29 and 11 (0.968810 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 13 (0.969645 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 18 (0.966470 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 6 (0.979661 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 16 (0.967702 A) is suspicious.
#   2%|▊                                      | 223/11000 [00:05<04:05, 43.85it/s]!!! Warning !!! Distance between atoms 19 and 1 (0.975725 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 12 (0.966972 A) is suspicious.
#   2%|▊                                      | 228/11000 [00:05<04:13, 42.50it/s]!!! Warning !!! Distance between atoms 32 and 12 (0.995378 A) is suspicious.
#   2%|▊                                      | 233/11000 [00:05<04:07, 43.48it/s]!!! Warning !!! Distance between atoms 26 and 1 (0.967845 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 25 (0.965873 A) is suspicious.
#   2%|▊                                      | 239/11000 [00:05<03:47, 47.24it/s]!!! Warning !!! Distance between atoms 38 and 9 (0.966360 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 16 (0.968839 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 23 (0.969952 A) is suspicious.
# !!! Warning !!! Distance between atoms 57 and 27 (0.968089 A) is suspicious.
#   2%|▊                                      | 244/11000 [00:06<04:08, 43.29it/s]!!! Warning !!! Distance between atoms 36 and 7 (0.966972 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 18 (0.965378 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 26 (0.969659 A) is suspicious.
#   2%|▉                                      | 250/11000 [00:06<04:04, 43.89it/s]!!! Warning !!! Distance between atoms 35 and 10 (0.964968 A) is suspicious.
#   2%|▉                                      | 261/11000 [00:06<04:08, 43.15it/s]!!! Warning !!! Distance between atoms 35 and 15 (0.968555 A) is suspicious.
#   3%|▉                                      | 281/11000 [00:07<04:09, 42.98it/s]!!! Warning !!! Distance between atoms 38 and 19 (0.966929 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 13 (0.967394 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 19 (0.970007 A) is suspicious.
#   3%|█                                      | 286/11000 [00:07<04:02, 44.17it/s]!!! Warning !!! Distance between atoms 28 and 3 (0.973589 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 4 (0.973426 A) is suspicious.
#   3%|█                                      | 291/11000 [00:07<04:26, 40.13it/s]!!! Warning !!! Distance between atoms 33 and 9 (0.966642 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 26 (0.967965 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 28 (0.968047 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 30 (0.969606 A) is suspicious.
#   3%|█                                      | 297/11000 [00:07<04:17, 41.52it/s]!!! Warning !!! Distance between atoms 53 and 28 (0.982282 A) is suspicious.
# !!! Warning !!! Distance between atoms 17 and 3 (0.974384 A) is suspicious.
#   3%|█                                      | 302/11000 [00:07<04:14, 42.04it/s]!!! Warning !!! Distance between atoms 25 and 14 (0.969921 A) is suspicious.
# !!! Warning !!! Distance between atoms 26 and 16 (0.969111 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 23 (0.973841 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 20 (0.968925 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 22 (0.968849 A) is suspicious.
#   3%|█                                      | 308/11000 [00:07<03:50, 46.36it/s]!!! Warning !!! Distance between atoms 35 and 7 (0.973907 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 6 (0.976065 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 10 (0.971379 A) is suspicious.
#   3%|█                                      | 313/11000 [00:07<03:54, 45.63it/s]!!! Warning !!! Distance between atoms 41 and 26 (0.974751 A) is suspicious.
#   3%|█▏                                     | 318/11000 [00:07<03:59, 44.64it/s]!!! Warning !!! Distance between atoms 31 and 10 (0.967573 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 12 (0.974606 A) is suspicious.
#   3%|█▏                                     | 323/11000 [00:07<04:06, 43.32it/s]!!! Warning !!! Distance between atoms 26 and 15 (0.973150 A) is suspicious.
#   3%|█▏                                     | 333/11000 [00:08<03:56, 45.01it/s]!!! Warning !!! Distance between atoms 29 and 3 (0.972915 A) is suspicious.
#   3%|█▏                                     | 338/11000 [00:08<04:12, 42.30it/s]!!! Warning !!! Distance between atoms 56 and 24 (0.965192 A) is suspicious.
#   3%|█▏                                     | 343/11000 [00:08<04:37, 38.40it/s]!!! Warning !!! Distance between atoms 26 and 5 (0.975904 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 11 (0.973825 A) is suspicious.
#   3%|█▏                                     | 348/11000 [00:08<04:18, 41.25it/s]!!! Warning !!! Distance between atoms 18 and 3 (0.973774 A) is suspicious.
#   3%|█▎                                     | 354/11000 [00:08<04:04, 43.48it/s]!!! Warning !!! Distance between atoms 34 and 8 (0.966369 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 1 (0.968016 A) is suspicious.
#   3%|█▎                                     | 372/11000 [00:09<04:52, 36.29it/s]!!! Warning !!! Distance between atoms 25 and 1 (0.978727 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 16 (0.967738 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 25 (0.968138 A) is suspicious.
# !!! Warning !!! Distance between atoms 52 and 30 (0.975581 A) is suspicious.
#   3%|█▎                                     | 384/11000 [00:09<05:07, 34.50it/s]!!! Warning !!! Distance between atoms 30 and 7 (0.968633 A) is suspicious.
# !!! Warning !!! Distance between atoms 59 and 20 (0.967385 A) is suspicious.
# !!! Warning !!! Distance between atoms 67 and 26 (0.967116 A) is suspicious.
# !!! Warning !!! Distance between atoms 45 and 15 (0.977214 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 19 (0.964896 A) is suspicious.
#   4%|█▍                                     | 396/11000 [00:10<05:45, 30.69it/s]!!! Warning !!! Distance between atoms 36 and 8 (0.966874 A) is suspicious.
#   4%|█▍                                     | 400/11000 [00:10<05:54, 29.90it/s]!!! Warning !!! Distance between atoms 18 and 6 (0.973721 A) is suspicious.
#   4%|█▍                                     | 405/11000 [00:10<05:25, 32.57it/s]!!! Warning !!! Distance between atoms 34 and 10 (0.968124 A) is suspicious.
#   4%|█▍                                     | 410/11000 [00:10<05:07, 34.47it/s]!!! Warning !!! Distance between atoms 38 and 14 (0.965945 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 16 (0.971889 A) is suspicious.
#   4%|█▍                                     | 416/11000 [00:10<04:33, 38.69it/s]!!! Warning !!! Distance between atoms 38 and 16 (0.971942 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 17 (0.971121 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 23 (0.971728 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 24 (0.971926 A) is suspicious.
#   4%|█▍                                     | 420/11000 [00:10<04:57, 35.54it/s]!!! Warning !!! Distance between atoms 55 and 23 (0.998760 A) is suspicious.
# !!! Warning !!! Distance between atoms 58 and 30 (0.970604 A) is suspicious.
#   4%|█▌                                     | 424/11000 [00:10<05:32, 31.85it/s]!!! Warning !!! Distance between atoms 33 and 15 (0.973994 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 20 (0.974089 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 11 (0.966609 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 13 (0.971821 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 28 (0.969207 A) is suspicious.
#   4%|█▌                                     | 428/11000 [00:10<05:24, 32.57it/s]!!! Warning !!! Distance between atoms 36 and 13 (0.966540 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 23 (0.967717 A) is suspicious.
#   4%|█▌                                     | 432/11000 [00:11<05:23, 32.70it/s]!!! Warning !!! Distance between atoms 28 and 1 (0.968797 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 14 (0.968298 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 23 (0.968401 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 14 (0.968444 A) is suspicious.
#   4%|█▌                                     | 436/11000 [00:11<05:31, 31.87it/s]!!! Warning !!! Distance between atoms 48 and 30 (0.971243 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 3 (0.974688 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 10 (0.968258 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 23 (0.968184 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 28 (0.974771 A) is suspicious.
#   4%|█▌                                     | 440/11000 [00:11<05:29, 32.05it/s]!!! Warning !!! Distance between atoms 26 and 8 (0.979609 A) is suspicious.
#   4%|█▌                                     | 444/11000 [00:11<05:10, 34.00it/s]!!! Warning !!! Distance between atoms 19 and 1 (0.970803 A) is suspicious.
#   4%|█▌                                     | 448/11000 [00:11<05:10, 34.02it/s]!!! Warning !!! Distance between atoms 27 and 3 (0.973531 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 21 (0.967704 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 18 (0.974806 A) is suspicious.
# !!! Warning !!! Distance between atoms 19 and 3 (0.974446 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 19 (0.964954 A) is suspicious.
#   4%|█▌                                     | 454/11000 [00:11<04:44, 37.12it/s]!!! Warning !!! Distance between atoms 35 and 12 (0.974155 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 16 (0.968311 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 19 (0.998396 A) is suspicious.
#   4%|█▌                                     | 458/11000 [00:11<04:50, 36.29it/s]!!! Warning !!! Distance between atoms 18 and 7 (0.970144 A) is suspicious.
# !!! Warning !!! Distance between atoms 19 and 9 (0.969092 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 16 (0.972532 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 19 (0.970930 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 3 (0.974443 A) is suspicious.
#   4%|█▋                                     | 464/11000 [00:11<04:32, 38.60it/s]!!! Warning !!! Distance between atoms 18 and 6 (0.972572 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 12 (0.973603 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 21 (0.966517 A) is suspicious.
#   4%|█▋                                     | 469/11000 [00:12<04:17, 40.86it/s]!!! Warning !!! Distance between atoms 31 and 14 (0.969356 A) is suspicious.
#   4%|█▋                                     | 479/11000 [00:12<04:33, 38.47it/s]!!! Warning !!! Distance between atoms 22 and 1 (0.973529 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 21 (0.977885 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 7 (0.974005 A) is suspicious.
#   4%|█▋                                     | 483/11000 [00:12<04:32, 38.59it/s]!!! Warning !!! Distance between atoms 37 and 10 (0.968050 A) is suspicious.
#   4%|█▋                                     | 489/11000 [00:12<04:11, 41.73it/s]!!! Warning !!! Distance between atoms 33 and 4 (0.969476 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 22 (0.972607 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 26 (0.974507 A) is suspicious.
# !!! Warning !!! Distance between atoms 22 and 1 (0.968957 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 14 (0.968989 A) is suspicious.
#   4%|█▊                                     | 494/11000 [00:12<04:11, 41.84it/s]!!! Warning !!! Distance between atoms 43 and 16 (0.967550 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 24 (0.969308 A) is suspicious.
#   5%|█▊                                     | 499/11000 [00:12<04:18, 40.69it/s]!!! Warning !!! Distance between atoms 28 and 12 (0.966802 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 14 (0.966817 A) is suspicious.
#   5%|█▊                                     | 509/11000 [00:13<04:17, 40.75it/s]!!! Warning !!! Distance between atoms 40 and 17 (0.974545 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 9 (0.973026 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 24 (0.968364 A) is suspicious.
#   5%|█▊                                     | 514/11000 [00:13<04:33, 38.28it/s]!!! Warning !!! Distance between atoms 18 and 1 (0.968370 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 17 (0.967811 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 3 (0.974038 A) is suspicious.
#   5%|█▊                                     | 520/11000 [00:13<04:25, 39.53it/s]!!! Warning !!! Distance between atoms 25 and 1 (0.973200 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 23 (0.966231 A) is suspicious.
#   5%|█▉                                     | 537/11000 [00:13<03:59, 43.67it/s]!!! Warning !!! Distance between atoms 29 and 1 (0.966446 A) is suspicious.
# !!! Warning !!! Distance between atoms 60 and 24 (0.968025 A) is suspicious.
#   5%|█▉                                     | 542/11000 [00:13<04:13, 41.33it/s]!!! Warning !!! Distance between atoms 54 and 26 (0.969087 A) is suspicious.
#   5%|█▉                                     | 547/11000 [00:13<04:04, 42.76it/s]!!! Warning !!! Distance between atoms 35 and 7 (0.967940 A) is suspicious.
# !!! Warning !!! Distance between atoms 20 and 1 (0.968051 A) is suspicious.
#   5%|█▉                                     | 552/11000 [00:14<04:21, 40.02it/s]!!! Warning !!! Distance between atoms 34 and 8 (0.974742 A) is suspicious.
# !!! Warning !!! Distance between atoms 22 and 3 (0.974149 A) is suspicious.
#   5%|█▉                                     | 557/11000 [00:14<04:06, 42.36it/s]!!! Warning !!! Distance between atoms 26 and 3 (0.974188 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 10 (0.969377 A) is suspicious.
#   5%|█▉                                     | 562/11000 [00:14<04:09, 41.87it/s]!!! Warning !!! Distance between atoms 32 and 7 (0.966791 A) is suspicious.
#   5%|██                                     | 576/11000 [00:14<04:44, 36.65it/s]!!! Warning !!! Distance between atoms 40 and 24 (0.968199 A) is suspicious.
#   5%|██                                     | 580/11000 [00:14<04:44, 36.68it/s]!!! Warning !!! Distance between atoms 37 and 20 (0.995764 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 20 (0.967441 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 1 (0.966813 A) is suspicious.
#   5%|██                                     | 586/11000 [00:14<04:30, 38.51it/s]!!! Warning !!! Distance between atoms 28 and 7 (0.981461 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 9 (0.969297 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 18 (0.969020 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 20 (0.968928 A) is suspicious.
#   5%|██                                     | 590/11000 [00:15<04:32, 38.24it/s]!!! Warning !!! Distance between atoms 35 and 3 (0.968296 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 3 (0.973408 A) is suspicious.
#   5%|██                                     | 595/11000 [00:15<04:24, 39.39it/s]!!! Warning !!! Distance between atoms 33 and 14 (0.967128 A) is suspicious.
#   5%|██▏                                    | 602/11000 [00:15<03:46, 46.00it/s]!!! Warning !!! Distance between atoms 29 and 3 (0.973940 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 13 (0.966722 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 16 (0.965434 A) is suspicious.
#   6%|██▏                                    | 617/11000 [00:15<04:04, 42.55it/s]!!! Warning !!! Distance between atoms 43 and 17 (0.968431 A) is suspicious.
#   6%|██▏                                    | 622/11000 [00:15<03:59, 43.26it/s]!!! Warning !!! Distance between atoms 11 and 1 (0.966224 A) is suspicious.
# !!! Warning !!! Distance between atoms 18 and 8 (0.966214 A) is suspicious.
# !!! Warning !!! Distance between atoms 20 and 10 (0.967393 A) is suspicious.
#   6%|██▎                                    | 638/11000 [00:16<04:34, 37.74it/s]!!! Warning !!! Distance between atoms 59 and 23 (0.969353 A) is suspicious.
#   6%|██▎                                    | 642/11000 [00:16<04:34, 37.79it/s]!!! Warning !!! Distance between atoms 32 and 20 (0.975406 A) is suspicious.
#   6%|██▎                                    | 649/11000 [00:16<03:47, 45.46it/s]!!! Warning !!! Distance between atoms 29 and 5 (0.971042 A) is suspicious.
#   6%|██▎                                    | 654/11000 [00:16<03:49, 45.01it/s]!!! Warning !!! Distance between atoms 51 and 29 (0.974146 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 1 (0.977038 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 26 (0.977102 A) is suspicious.
#   6%|██▎                                    | 664/11000 [00:16<04:21, 39.55it/s]!!! Warning !!! Distance between atoms 12 and 1 (0.971672 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 25 (0.974190 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 30 (0.969589 A) is suspicious.
#   6%|██▎                                    | 669/11000 [00:16<04:24, 39.09it/s]!!! Warning !!! Distance between atoms 28 and 1 (0.967638 A) is suspicious.
# !!! Warning !!! Distance between atoms 54 and 27 (0.968514 A) is suspicious.
#   6%|██▍                                    | 678/11000 [00:17<04:37, 37.26it/s]!!! Warning !!! Distance between atoms 37 and 19 (0.974048 A) is suspicious.
#   6%|██▍                                    | 682/11000 [00:17<04:40, 36.85it/s]!!! Warning !!! Distance between atoms 30 and 18 (0.966211 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 20 (0.969152 A) is suspicious.
#   6%|██▍                                    | 686/11000 [00:17<04:35, 37.43it/s]!!! Warning !!! Distance between atoms 45 and 24 (0.964979 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 20 (0.973923 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 6 (0.975123 A) is suspicious.
#   6%|██▍                                    | 690/11000 [00:17<04:52, 35.21it/s]!!! Warning !!! Distance between atoms 26 and 3 (0.973939 A) is suspicious.
#   6%|██▍                                    | 695/11000 [00:17<04:45, 36.12it/s]!!! Warning !!! Distance between atoms 25 and 1 (0.968606 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 19 (0.968881 A) is suspicious.
#   6%|██▍                                    | 699/11000 [00:17<04:44, 36.15it/s]!!! Warning !!! Distance between atoms 48 and 15 (0.966798 A) is suspicious.
# !!! Warning !!! Distance between atoms 52 and 18 (0.968547 A) is suspicious.
# !!! Warning !!! Distance between atoms 55 and 22 (0.974607 A) is suspicious.
#   6%|██▌                                    | 708/11000 [00:18<04:56, 34.67it/s]!!! Warning !!! Distance between atoms 23 and 3 (0.973968 A) is suspicious.
# !!! Warning !!! Distance between atoms 52 and 15 (0.968146 A) is suspicious.
# !!! Warning !!! Distance between atoms 56 and 18 (0.979048 A) is suspicious.
#   7%|██▌                                    | 717/11000 [00:18<04:38, 36.98it/s]!!! Warning !!! Distance between atoms 48 and 26 (0.971325 A) is suspicious.
#   7%|██▌                                    | 726/11000 [00:18<04:43, 36.22it/s]!!! Warning !!! Distance between atoms 44 and 23 (0.968366 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 9 (0.971538 A) is suspicious.
#   7%|██▌                                    | 730/11000 [00:18<05:09, 33.19it/s]!!! Warning !!! Distance between atoms 37 and 22 (0.973708 A) is suspicious.
#   7%|██▌                                    | 735/11000 [00:18<04:37, 37.01it/s]!!! Warning !!! Distance between atoms 45 and 17 (0.969203 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 5 (0.964783 A) is suspicious.
#   7%|██▋                                    | 753/11000 [00:19<04:37, 36.95it/s]!!! Warning !!! Distance between atoms 53 and 22 (0.966671 A) is suspicious.
# !!! Warning !!! Distance between atoms 55 and 24 (0.981348 A) is suspicious.
# !!! Warning !!! Distance between atoms 57 and 26 (0.966343 A) is suspicious.
#   7%|██▋                                    | 762/11000 [00:19<04:15, 40.04it/s]!!! Warning !!! Distance between atoms 43 and 21 (0.966936 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 24 (0.979403 A) is suspicious.
#   7%|██▋                                    | 767/11000 [00:19<04:05, 41.63it/s]!!! Warning !!! Distance between atoms 24 and 10 (0.972385 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 11 (0.966264 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 3 (0.974209 A) is suspicious.
#   7%|██▋                                    | 773/11000 [00:19<03:47, 44.89it/s]!!! Warning !!! Distance between atoms 35 and 9 (0.965039 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 25 (0.969144 A) is suspicious.
#   7%|██▊                                    | 778/11000 [00:19<03:58, 42.79it/s]!!! Warning !!! Distance between atoms 38 and 16 (0.970637 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 13 (0.974032 A) is suspicious.
#   7%|██▊                                    | 783/11000 [00:20<03:57, 42.97it/s]!!! Warning !!! Distance between atoms 28 and 3 (0.974083 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 19 (0.973080 A) is suspicious.
#   7%|██▊                                    | 790/11000 [00:20<03:40, 46.26it/s]!!! Warning !!! Distance between atoms 32 and 5 (0.967862 A) is suspicious.
#   7%|██▊                                    | 795/11000 [00:20<03:57, 43.06it/s]!!! Warning !!! Distance between atoms 30 and 8 (0.973888 A) is suspicious.
# !!! Warning !!! Distance between atoms 17 and 3 (0.974284 A) is suspicious.
# !!! Warning !!! Distance between atoms 18 and 4 (0.973054 A) is suspicious.
# !!! Warning !!! Distance between atoms 19 and 10 (0.989698 A) is suspicious.
# !!! Warning !!! Distance between atoms 17 and 4 (0.983320 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 19 (0.969035 A) is suspicious.
#   7%|██▊                                    | 804/11000 [00:20<03:15, 52.26it/s]!!! Warning !!! Distance between atoms 42 and 24 (0.968505 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 9 (0.973815 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 8 (0.968711 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 10 (0.977023 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 19 (0.968538 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 21 (0.970073 A) is suspicious.
#   7%|██▊                                    | 810/11000 [00:20<03:09, 53.81it/s]!!! Warning !!! Distance between atoms 28 and 3 (0.974107 A) is suspicious.
#   7%|██▉                                    | 816/11000 [00:20<03:24, 49.80it/s]!!! Warning !!! Distance between atoms 24 and 12 (0.965262 A) is suspicious.
#   7%|██▉                                    | 822/11000 [00:20<03:59, 42.46it/s]!!! Warning !!! Distance between atoms 34 and 17 (0.966966 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 20 (0.973245 A) is suspicious.
#   8%|██▉                                    | 827/11000 [00:20<04:05, 41.41it/s]!!! Warning !!! Distance between atoms 17 and 5 (0.970109 A) is suspicious.
# !!! Warning !!! Distance between atoms 53 and 28 (0.974171 A) is suspicious.
#   8%|██▉                                    | 833/11000 [00:21<03:51, 43.89it/s]!!! Warning !!! Distance between atoms 31 and 8 (0.967165 A) is suspicious.
#   8%|██▉                                    | 839/11000 [00:21<03:37, 46.80it/s]!!! Warning !!! Distance between atoms 31 and 12 (0.967348 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 14 (0.968343 A) is suspicious.
#   8%|███                                    | 849/11000 [00:21<04:03, 41.76it/s]!!! Warning !!! Distance between atoms 23 and 8 (0.973619 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 7 (0.970080 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 10 (0.991154 A) is suspicious.
#   8%|███                                    | 861/11000 [00:21<03:48, 44.38it/s]!!! Warning !!! Distance between atoms 21 and 3 (0.973274 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 7 (0.968612 A) is suspicious.
#   8%|███                                    | 866/11000 [00:21<04:02, 41.72it/s]!!! Warning !!! Distance between atoms 37 and 10 (0.977694 A) is suspicious.
# !!! Warning !!! Distance between atoms 20 and 6 (0.966960 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 13 (0.968733 A) is suspicious.
#   8%|███                                    | 871/11000 [00:21<04:07, 40.95it/s]!!! Warning !!! Distance between atoms 25 and 12 (0.970239 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 20 (0.974861 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 26 (0.975151 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 20 (0.967505 A) is suspicious.
#   8%|███                                    | 881/11000 [00:22<04:15, 39.54it/s]!!! Warning !!! Distance between atoms 54 and 25 (0.968166 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 18 (0.971262 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 6 (0.998136 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 10 (0.974371 A) is suspicious.
#   8%|███▏                                   | 886/11000 [00:22<04:12, 40.06it/s]!!! Warning !!! Distance between atoms 35 and 13 (0.969083 A) is suspicious.
#   8%|███▏                                   | 896/11000 [00:22<04:22, 38.46it/s]!!! Warning !!! Distance between atoms 22 and 1 (0.966343 A) is suspicious.
# !!! Warning !!! Distance between atoms 57 and 27 (0.969270 A) is suspicious.
#   8%|███▏                                   | 904/11000 [00:22<04:42, 35.80it/s]!!! Warning !!! Distance between atoms 23 and 9 (0.973213 A) is suspicious.
#   8%|███▎                                   | 935/11000 [00:23<04:39, 36.06it/s]!!! Warning !!! Distance between atoms 20 and 1 (0.968235 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 6 (0.981534 A) is suspicious.
#   9%|███▎                                   | 942/11000 [00:23<03:59, 42.03it/s]!!! Warning !!! Distance between atoms 47 and 27 (0.982565 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 8 (0.969310 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 23 (0.968630 A) is suspicious.
#   9%|███▎                                   | 947/11000 [00:24<04:19, 38.75it/s]!!! Warning !!! Distance between atoms 40 and 17 (0.967898 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 16 (0.966853 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 11 (0.975787 A) is suspicious.
#   9%|███▍                                   | 953/11000 [00:24<04:01, 41.59it/s]!!! Warning !!! Distance between atoms 29 and 10 (0.966286 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 29 (0.971164 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 30 (0.971319 A) is suspicious.
#   9%|███▍                                   | 959/11000 [00:24<03:53, 42.98it/s]!!! Warning !!! Distance between atoms 34 and 6 (0.969508 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 9 (0.973037 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 12 (0.971471 A) is suspicious.
#   9%|███▍                                   | 964/11000 [00:24<03:56, 42.52it/s]!!! Warning !!! Distance between atoms 40 and 24 (0.969082 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 6 (0.967896 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 13 (0.965711 A) is suspicious.
# !!! Warning !!! Distance between atoms 71 and 28 (0.965803 A) is suspicious.
#   9%|███▍                                   | 969/11000 [00:24<04:18, 38.74it/s]!!! Warning !!! Distance between atoms 31 and 9 (0.977860 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 15 (0.973850 A) is suspicious.
# !!! Warning !!! Distance between atoms 26 and 9 (0.969065 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 20 (0.968081 A) is suspicious.
#   9%|███▍                                   | 974/11000 [00:24<04:06, 40.70it/s]!!! Warning !!! Distance between atoms 44 and 19 (0.969137 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 29 (0.969306 A) is suspicious.
#   9%|███▍                                   | 979/11000 [00:24<04:01, 41.51it/s]!!! Warning !!! Distance between atoms 19 and 6 (0.967265 A) is suspicious.
# !!! Warning !!! Distance between atoms 22 and 11 (0.969672 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 13 (0.968985 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 1 (0.972547 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 3 (0.967137 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 5 (0.990250 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 10 (0.968024 A) is suspicious.
#   9%|███▍                                   | 984/11000 [00:24<04:09, 40.19it/s]!!! Warning !!! Distance between atoms 36 and 5 (0.965241 A) is suspicious.
#   9%|███▌                                   | 989/11000 [00:25<04:09, 40.16it/s]!!! Warning !!! Distance between atoms 24 and 11 (0.975670 A) is suspicious.
# !!! Warning !!! Distance between atoms 26 and 13 (0.965855 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 15 (0.969395 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 17 (0.973977 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 13 (0.973244 A) is suspicious.
#   9%|███▌                                   | 999/11000 [00:25<04:17, 38.83it/s]!!! Warning !!! Distance between atoms 29 and 9 (0.969116 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 12 (0.970211 A) is suspicious.
# !!! Warning !!! Distance between atoms 19 and 3 (0.974426 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 16 (0.966472 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 18 (0.966078 A) is suspicious.
#   9%|███▍                                  | 1004/11000 [00:25<04:19, 38.55it/s]!!! Warning !!! Distance between atoms 39 and 14 (0.968350 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 16 (0.967685 A) is suspicious.
#   9%|███▍                                  | 1008/11000 [00:25<04:19, 38.48it/s]!!! Warning !!! Distance between atoms 48 and 13 (0.969676 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 16 (0.989758 A) is suspicious.
# !!! Warning !!! Distance between atoms 58 and 28 (0.972177 A) is suspicious.
#   9%|███▍                                  | 1012/11000 [00:25<04:42, 35.32it/s]!!! Warning !!! Distance between atoms 48 and 25 (0.973735 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 1 (0.966925 A) is suspicious.
#   9%|███▌                                  | 1017/11000 [00:25<04:30, 36.94it/s]!!! Warning !!! Distance between atoms 40 and 14 (0.974400 A) is suspicious.
# !!! Warning !!! Distance between atoms 45 and 26 (0.973803 A) is suspicious.
#   9%|███▌                                  | 1021/11000 [00:25<04:32, 36.65it/s]!!! Warning !!! Distance between atoms 21 and 1 (0.968116 A) is suspicious.
#   9%|███▌                                  | 1025/11000 [00:26<04:47, 34.66it/s]!!! Warning !!! Distance between atoms 47 and 21 (0.967965 A) is suspicious.
# !!! Warning !!! Distance between atoms 54 and 28 (0.982249 A) is suspicious.
#   9%|███▌                                  | 1035/11000 [00:26<04:26, 37.37it/s]!!! Warning !!! Distance between atoms 29 and 3 (0.972750 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 28 (0.977311 A) is suspicious.
#   9%|███▌                                  | 1039/11000 [00:26<04:50, 34.24it/s]!!! Warning !!! Distance between atoms 27 and 3 (0.974161 A) is suspicious.
#  10%|███▌                                  | 1047/11000 [00:26<05:07, 32.34it/s]!!! Warning !!! Distance between atoms 37 and 19 (0.968335 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 9 (0.967454 A) is suspicious.
#  10%|███▋                                  | 1051/11000 [00:26<05:27, 30.37it/s]!!! Warning !!! Distance between atoms 31 and 12 (0.968098 A) is suspicious.
#  10%|███▋                                  | 1055/11000 [00:26<05:19, 31.09it/s]!!! Warning !!! Distance between atoms 32 and 6 (0.968970 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 20 (0.996374 A) is suspicious.
#  10%|███▋                                  | 1059/11000 [00:27<05:19, 31.14it/s]!!! Warning !!! Distance between atoms 30 and 5 (0.966351 A) is suspicious.
# !!! Warning !!! Distance between atoms 26 and 1 (0.967402 A) is suspicious.
#  10%|███▋                                  | 1071/11000 [00:27<03:47, 43.55it/s]!!! Warning !!! Distance between atoms 53 and 18 (0.970037 A) is suspicious.
# !!! Warning !!! Distance between atoms 56 and 23 (0.971326 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 17 (0.968271 A) is suspicious.
# !!! Warning !!! Distance between atoms 41 and 22 (0.970107 A) is suspicious.
#  10%|███▋                                  | 1076/11000 [00:27<04:04, 40.57it/s]!!! Warning !!! Distance between atoms 37 and 16 (0.969450 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 19 (0.968921 A) is suspicious.
#  10%|███▋                                  | 1081/11000 [00:27<04:02, 40.92it/s]!!! Warning !!! Distance between atoms 34 and 11 (0.972535 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 15 (0.973872 A) is suspicious.
#  10%|███▊                                  | 1091/11000 [00:27<04:09, 39.75it/s]!!! Warning !!! Distance between atoms 23 and 5 (0.967745 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 8 (0.983166 A) is suspicious.
#  10%|███▊                                  | 1096/11000 [00:27<04:01, 40.99it/s]!!! Warning !!! Distance between atoms 37 and 21 (0.973829 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 16 (0.994903 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 22 (0.994624 A) is suspicious.
#  10%|███▊                                  | 1101/11000 [00:28<04:07, 39.97it/s]!!! Warning !!! Distance between atoms 37 and 16 (0.966684 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 21 (0.972069 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 23 (0.966690 A) is suspicious.
#  10%|███▊                                  | 1107/11000 [00:28<03:41, 44.73it/s]!!! Warning !!! Distance between atoms 33 and 6 (0.967571 A) is suspicious.
# !!! Warning !!! Distance between atoms 45 and 17 (0.983265 A) is suspicious.
# !!! Warning !!! Distance between atoms 52 and 28 (0.976443 A) is suspicious.
#  10%|███▊                                  | 1112/11000 [00:28<03:50, 42.94it/s]!!! Warning !!! Distance between atoms 32 and 9 (0.970964 A) is suspicious.
#  10%|███▉                                  | 1122/11000 [00:28<04:17, 38.41it/s]!!! Warning !!! Distance between atoms 42 and 16 (0.973777 A) is suspicious.
#  10%|███▉                                  | 1127/11000 [00:28<04:03, 40.54it/s]!!! Warning !!! Distance between atoms 43 and 15 (0.968206 A) is suspicious.
#  10%|███▉                                  | 1132/11000 [00:28<04:06, 40.11it/s]!!! Warning !!! Distance between atoms 28 and 11 (0.965971 A) is suspicious.
#  10%|███▉                                  | 1137/11000 [00:28<04:06, 40.05it/s]!!! Warning !!! Distance between atoms 19 and 1 (0.968080 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 12 (0.967809 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 12 (0.968861 A) is suspicious.
#  10%|███▉                                  | 1142/11000 [00:29<04:09, 39.54it/s]!!! Warning !!! Distance between atoms 29 and 3 (0.974079 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 26 (0.974783 A) is suspicious.
#  10%|███▉                                  | 1147/11000 [00:29<04:01, 40.88it/s]!!! Warning !!! Distance between atoms 34 and 14 (0.983321 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 20 (0.975006 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 21 (0.974825 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 23 (0.967002 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 25 (0.971403 A) is suspicious.
#  10%|███▉                                  | 1152/11000 [00:29<03:47, 43.22it/s]!!! Warning !!! Distance between atoms 39 and 23 (0.973635 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 3 (0.974946 A) is suspicious.
# !!! Warning !!! Distance between atoms 24 and 18 (0.985707 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 20 (0.969518 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 22 (0.968441 A) is suspicious.
#  11%|████                                  | 1163/11000 [00:29<03:52, 42.31it/s]!!! Warning !!! Distance between atoms 39 and 15 (0.965667 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 8 (0.969125 A) is suspicious.
# !!! Warning !!! Distance between atoms 53 and 22 (0.968430 A) is suspicious.
# !!! Warning !!! Distance between atoms 54 and 24 (0.968438 A) is suspicious.
# !!! Warning !!! Distance between atoms 55 and 26 (0.969471 A) is suspicious.
#  11%|████                                  | 1168/11000 [00:29<04:43, 34.65it/s]!!! Warning !!! Distance between atoms 27 and 7 (0.973454 A) is suspicious.
# !!! Warning !!! Distance between atoms 29 and 14 (0.972985 A) is suspicious.
# ...
# !!! Warning !!! Distance between atoms 34 and 18 (0.981778 A) is suspicious.
#  97%|███████████████████████████████████▉ | 10666/11000 [05:27<00:10, 31.32it/s]!!! Warning !!! Distance between atoms 46 and 15 (0.969034 A) is suspicious.
#  97%|███████████████████████████████████▉ | 10677/11000 [05:28<00:11, 27.75it/s]!!! Warning !!! Distance between atoms 48 and 20 (0.964687 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 27 (0.976878 A) is suspicious.
#  97%|███████████████████████████████████▉ | 10683/11000 [05:28<00:12, 25.90it/s]!!! Warning !!! Distance between atoms 25 and 4 (0.970259 A) is suspicious.
#  97%|███████████████████████████████████▉ | 10687/11000 [05:28<00:11, 28.32it/s]!!! Warning !!! Distance between atoms 37 and 14 (0.968972 A) is suspicious.
# !!! Warning !!! Distance between atoms 45 and 20 (0.984195 A) is suspicious.
#  97%|███████████████████████████████████▉ | 10696/11000 [05:28<00:09, 31.94it/s]!!! Warning !!! Distance between atoms 31 and 4 (0.964630 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 5 (0.987812 A) is suspicious.
# !!! Warning !!! Distance between atoms 45 and 17 (0.973036 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 18 (0.973405 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 21 (0.997211 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 22 (0.971514 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 26 (0.967417 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 4 (0.967426 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 17 (0.967060 A) is suspicious.
#  97%|███████████████████████████████████▉ | 10700/11000 [05:28<00:09, 30.12it/s]!!! Warning !!! Distance between atoms 27 and 8 (0.980727 A) is suspicious.
#  97%|████████████████████████████████████ | 10706/11000 [05:29<00:08, 34.92it/s]!!! Warning !!! Distance between atoms 46 and 26 (0.981704 A) is suspicious.
#  97%|████████████████████████████████████ | 10710/11000 [05:29<00:08, 32.44it/s]!!! Warning !!! Distance between atoms 49 and 16 (0.966030 A) is suspicious.
#  97%|████████████████████████████████████ | 10714/11000 [05:29<00:08, 32.51it/s]!!! Warning !!! Distance between atoms 45 and 28 (0.969404 A) is suspicious.
#  97%|████████████████████████████████████ | 10718/11000 [05:29<00:08, 31.49it/s]!!! Warning !!! Distance between atoms 57 and 26 (0.991411 A) is suspicious.
#  98%|████████████████████████████████████ | 10727/11000 [05:29<00:09, 29.90it/s]!!! Warning !!! Distance between atoms 49 and 17 (0.965237 A) is suspicious.
# !!! Warning !!! Distance between atoms 53 and 20 (0.966221 A) is suspicious.
# !!! Warning !!! Distance between atoms 27 and 8 (0.967788 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 19 (0.963219 A) is suspicious.
#  98%|████████████████████████████████████ | 10738/11000 [05:30<00:08, 31.06it/s]!!! Warning !!! Distance between atoms 45 and 24 (0.975435 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 11 (0.984319 A) is suspicious.
#  98%|████████████████████████████████████▏| 10742/11000 [05:30<00:08, 31.27it/s]!!! Warning !!! Distance between atoms 46 and 13 (0.973192 A) is suspicious.
# !!! Warning !!! Distance between atoms 58 and 29 (0.968676 A) is suspicious.
#  98%|████████████████████████████████████▏| 10747/11000 [05:30<00:07, 32.88it/s]!!! Warning !!! Distance between atoms 36 and 7 (0.966846 A) is suspicious.
#  98%|████████████████████████████████████▏| 10751/11000 [05:30<00:07, 32.47it/s]!!! Warning !!! Distance between atoms 50 and 25 (0.967003 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 9 (0.967331 A) is suspicious.
#  98%|████████████████████████████████████▏| 10755/11000 [05:30<00:07, 33.63it/s]!!! Warning !!! Distance between atoms 38 and 17 (0.967956 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 9 (0.971609 A) is suspicious.
#  98%|████████████████████████████████████▏| 10763/11000 [05:30<00:07, 31.98it/s]!!! Warning !!! Distance between atoms 47 and 31 (0.968944 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 28 (0.965312 A) is suspicious.
#  98%|████████████████████████████████████▏| 10774/11000 [05:31<00:08, 27.33it/s]!!! Warning !!! Distance between atoms 61 and 29 (0.970678 A) is suspicious.
#  98%|████████████████████████████████████▏| 10777/11000 [05:31<00:08, 26.97it/s]!!! Warning !!! Distance between atoms 37 and 27 (0.984864 A) is suspicious.
# !!! Warning !!! Distance between atoms 64 and 31 (0.969035 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 11 (0.969258 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 13 (0.971299 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 15 (0.967869 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 17 (0.967547 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 10 (0.976687 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 17 (0.986353 A) is suspicious.
#  98%|████████████████████████████████████▎| 10780/11000 [05:31<00:08, 26.80it/s]!!! Warning !!! Distance between atoms 44 and 22 (0.968518 A) is suspicious.
#  98%|████████████████████████████████████▎| 10784/11000 [05:31<00:07, 29.39it/s]!!! Warning !!! Distance between atoms 34 and 8 (0.972495 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 11 (0.967832 A) is suspicious.
#  98%|████████████████████████████████████▎| 10788/11000 [05:31<00:06, 30.67it/s]!!! Warning !!! Distance between atoms 44 and 24 (0.967784 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 27 (0.967954 A) is suspicious.
#  98%|████████████████████████████████████▎| 10796/11000 [05:32<00:06, 32.42it/s]!!! Warning !!! Distance between atoms 36 and 15 (0.968261 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 24 (0.966393 A) is suspicious.
#  98%|████████████████████████████████████▎| 10800/11000 [05:32<00:06, 29.29it/s]!!! Warning !!! Distance between atoms 38 and 13 (0.973401 A) is suspicious.
#  98%|████████████████████████████████████▎| 10808/11000 [05:32<00:06, 29.90it/s]!!! Warning !!! Distance between atoms 55 and 25 (0.967126 A) is suspicious.
#  98%|████████████████████████████████████▎| 10813/11000 [05:32<00:05, 33.21it/s]!!! Warning !!! Distance between atoms 21 and 7 (0.969330 A) is suspicious.
# !!! Warning !!! Distance between atoms 22 and 9 (0.967065 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 15 (0.975256 A) is suspicious.
# !!! Warning !!! Distance between atoms 30 and 6 (0.970587 A) is suspicious.
#  98%|████████████████████████████████████▍| 10818/11000 [05:32<00:05, 34.37it/s]!!! Warning !!! Distance between atoms 36 and 18 (0.975136 A) is suspicious.
#  98%|████████████████████████████████████▍| 10822/11000 [05:32<00:05, 34.84it/s]!!! Warning !!! Distance between atoms 31 and 3 (0.978505 A) is suspicious.
#  98%|████████████████████████████████████▍| 10831/11000 [05:33<00:04, 35.00it/s]!!! Warning !!! Distance between atoms 56 and 29 (0.969069 A) is suspicious.
# !!! Warning !!! Distance between atoms 58 and 31 (0.970195 A) is suspicious.
#  98%|████████████████████████████████████▍| 10835/11000 [05:33<00:04, 33.30it/s]!!! Warning !!! Distance between atoms 24 and 3 (0.967548 A) is suspicious.
# !!! Warning !!! Distance between atoms 40 and 23 (0.969841 A) is suspicious.
#  99%|████████████████████████████████████▍| 10840/11000 [05:33<00:04, 35.47it/s]!!! Warning !!! Distance between atoms 28 and 12 (0.973490 A) is suspicious.
# !!! Warning !!! Distance between atoms 54 and 30 (0.973586 A) is suspicious.
#  99%|████████████████████████████████████▍| 10844/11000 [05:33<00:04, 33.00it/s]!!! Warning !!! Distance between atoms 45 and 20 (0.965963 A) is suspicious.
# !!! Warning !!! Distance between atoms 47 and 22 (0.966574 A) is suspicious.
# !!! Warning !!! Distance between atoms 49 and 24 (0.968664 A) is suspicious.
# !!! Warning !!! Distance between atoms 51 and 26 (0.965477 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 4 (0.960122 A) is suspicious.
#  99%|████████████████████████████████████▌| 10852/11000 [05:33<00:04, 29.68it/s]!!! Warning !!! Distance between atoms 33 and 10 (0.967495 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 19 (0.974281 A) is suspicious.
#  99%|████████████████████████████████████▌| 10856/11000 [05:33<00:04, 30.61it/s]!!! Warning !!! Distance between atoms 45 and 20 (0.967422 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 19 (0.972914 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 5 (0.966550 A) is suspicious.
# !!! Warning !!! Distance between atoms 56 and 24 (0.992711 A) is suspicious.
# !!! Warning !!! Distance between atoms 57 and 28 (0.973746 A) is suspicious.
#  99%|████████████████████████████████████▌| 10860/11000 [05:34<00:04, 30.92it/s]!!! Warning !!! Distance between atoms 53 and 22 (0.964756 A) is suspicious.
# !!! Warning !!! Distance between atoms 58 and 30 (0.971975 A) is suspicious.
# !!! Warning !!! Distance between atoms 50 and 26 (0.968564 A) is suspicious.
#  99%|████████████████████████████████████▌| 10864/11000 [05:34<00:04, 30.27it/s]!!! Warning !!! Distance between atoms 24 and 4 (0.967453 A) is suspicious.
#  99%|████████████████████████████████████▌| 10877/11000 [05:34<00:03, 33.79it/s]!!! Warning !!! Distance between atoms 44 and 19 (0.970290 A) is suspicious.
#  99%|████████████████████████████████████▌| 10882/11000 [05:34<00:03, 37.95it/s]!!! Warning !!! Distance between atoms 30 and 10 (0.973610 A) is suspicious.
# !!! Warning !!! Distance between atoms 28 and 7 (0.968547 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 17 (0.966129 A) is suspicious.
#  99%|████████████████████████████████████▌| 10887/11000 [05:34<00:02, 38.27it/s]!!! Warning !!! Distance between atoms 58 and 27 (0.970762 A) is suspicious.
# !!! Warning !!! Distance between atoms 60 and 29 (0.968275 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 17 (0.968686 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 25 (0.965703 A) is suspicious.
#  99%|████████████████████████████████████▋| 10891/11000 [05:34<00:03, 31.80it/s]!!! Warning !!! Distance between atoms 45 and 24 (0.969200 A) is suspicious.
#  99%|████████████████████████████████████▋| 10895/11000 [05:35<00:03, 30.17it/s]!!! Warning !!! Distance between atoms 30 and 11 (0.969673 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 13 (0.971262 A) is suspicious.
#  99%|████████████████████████████████████▋| 10899/11000 [05:35<00:03, 29.89it/s]!!! Warning !!! Distance between atoms 42 and 11 (0.966920 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 13 (0.965804 A) is suspicious.
# !!! Warning !!! Distance between atoms 46 and 15 (0.965650 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 17 (0.967826 A) is suspicious.
#  99%|████████████████████████████████████▋| 10903/11000 [05:35<00:03, 27.52it/s]!!! Warning !!! Distance between atoms 47 and 26 (0.973448 A) is suspicious.
#  99%|████████████████████████████████████▋| 10906/11000 [05:35<00:03, 26.82it/s]!!! Warning !!! Distance between atoms 52 and 23 (0.962611 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 9 (0.989722 A) is suspicious.
#  99%|████████████████████████████████████▋| 10909/11000 [05:35<00:03, 25.67it/s]!!! Warning !!! Distance between atoms 29 and 4 (0.967372 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 10 (0.986522 A) is suspicious.
# !!! Warning !!! Distance between atoms 37 and 12 (0.971612 A) is suspicious.
#  99%|████████████████████████████████████▋| 10913/11000 [05:35<00:03, 27.89it/s]!!! Warning !!! Distance between atoms 37 and 14 (0.968436 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 16 (0.968637 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 20 (0.966748 A) is suspicious.
# !!! Warning !!! Distance between atoms 54 and 26 (0.967668 A) is suspicious.
# !!! Warning !!! Distance between atoms 55 and 28 (0.968975 A) is suspicious.
#  99%|████████████████████████████████████▋| 10916/11000 [05:35<00:03, 26.90it/s]!!! Warning !!! Distance between atoms 33 and 7 (0.966008 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 3 (0.968616 A) is suspicious.
# !!! Warning !!! Distance between atoms 35 and 6 (0.968113 A) is suspicious.
#  99%|████████████████████████████████████▋| 10920/11000 [05:35<00:02, 29.29it/s]!!! Warning !!! Distance between atoms 38 and 21 (0.969079 A) is suspicious.
# !!! Warning !!! Distance between atoms 39 and 23 (0.968556 A) is suspicious.
# !!! Warning !!! Distance between atoms 38 and 19 (0.972913 A) is suspicious.
#  99%|████████████████████████████████████▋| 10925/11000 [05:36<00:02, 33.36it/s]!!! Warning !!! Distance between atoms 37 and 9 (0.968157 A) is suspicious.
# !!! Warning !!! Distance between atoms 43 and 19 (0.968036 A) is suspicious.
# !!! Warning !!! Distance between atoms 48 and 26 (0.967863 A) is suspicious.
#  99%|████████████████████████████████████▊| 10933/11000 [05:36<00:02, 32.86it/s]!!! Warning !!! Distance between atoms 38 and 10 (0.974319 A) is suspicious.
#  99%|████████████████████████████████████▊| 10937/11000 [05:36<00:02, 31.17it/s]!!! Warning !!! Distance between atoms 36 and 13 (0.973491 A) is suspicious.
#  99%|████████████████████████████████████▊| 10941/11000 [05:36<00:01, 30.87it/s]!!! Warning !!! Distance between atoms 30 and 10 (0.966973 A) is suspicious.
# !!! Warning !!! Distance between atoms 44 and 17 (0.981414 A) is suspicious.
# 100%|████████████████████████████████████▊| 10946/11000 [05:36<00:01, 34.10it/s]!!! Warning !!! Distance between atoms 36 and 20 (0.970286 A) is suspicious.
# 100%|████████████████████████████████████▊| 10950/11000 [05:36<00:01, 33.89it/s]!!! Warning !!! Distance between atoms 38 and 9 (0.971764 A) is suspicious.
# 100%|████████████████████████████████████▊| 10954/11000 [05:36<00:01, 32.36it/s]!!! Warning !!! Distance between atoms 33 and 9 (0.968496 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 11 (0.966163 A) is suspicious.
# !!! Warning !!! Distance between atoms 26 and 10 (0.967952 A) is suspicious.
# !!! Warning !!! Distance between atoms 31 and 17 (0.968019 A) is suspicious.
# 100%|████████████████████████████████████▉| 10963/11000 [05:37<00:01, 35.17it/s]!!! Warning !!! Distance between atoms 36 and 15 (0.968946 A) is suspicious.
# 100%|████████████████████████████████████▉| 10971/11000 [05:37<00:00, 33.03it/s]!!! Warning !!! Distance between atoms 29 and 4 (0.966003 A) is suspicious.
# 100%|████████████████████████████████████▉| 10975/11000 [05:37<00:00, 32.80it/s]!!! Warning !!! Distance between atoms 37 and 10 (0.963868 A) is suspicious.
# !!! Warning !!! Distance between atoms 45 and 10 (0.980577 A) is suspicious.
# 100%|████████████████████████████████████▉| 10979/11000 [05:37<00:00, 33.45it/s]!!! Warning !!! Distance between atoms 40 and 2 (0.987120 A) is suspicious.
# 100%|████████████████████████████████████▉| 10983/11000 [05:37<00:00, 32.33it/s]!!! Warning !!! Distance between atoms 62 and 18 (0.971193 A) is suspicious.
# !!! Warning !!! Distance between atoms 65 and 21 (0.971819 A) is suspicious.
# !!! Warning !!! Distance between atoms 69 and 25 (0.968729 A) is suspicious.
# !!! Warning !!! Distance between atoms 71 and 27 (0.966001 A) is suspicious.
# 100%|████████████████████████████████████▉| 10992/11000 [05:38<00:00, 34.44it/s]!!! Warning !!! Distance between atoms 37 and 16 (0.972658 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 22 (0.982598 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 13 (0.972206 A) is suspicious.
# 100%|████████████████████████████████████▉| 10996/11000 [05:38<00:00, 32.64it/s]!!! Warning !!! Distance between atoms 38 and 15 (0.973645 A) is suspicious.
# 100%|█████████████████████████████████████| 11000/11000 [05:38<00:00, 32.51it/s]
# 100%|████████████████████████████████████| 11000/11000 [00:17<00:00, 617.08it/s]

# %%
import os
import tarfile

out_dir = './confs_optimized_by_orca'

def load_index_as_list(path):
    with open(path, 'r') as f:
        idx_list = [s.strip() for s in f.readlines()]
    return idx_list

rct_idx  = load_index_as_list('df_sample_10000_sanity.index')
nuc_idx  = load_index_as_list('df_nuc_sample_10000_sanity.index')
elec_idx = load_index_as_list('df_elec_sample_10000_sanity.index')

nuc_idx_set  = [idx.split('_')[0] for idx in load_index_as_list('df_nuc_sample_10000_sanity.index')]
elec_idx_set = [idx.split('_')[0] for idx in load_index_as_list('df_elec_sample_10000_sanity.index')]

idx_to_analyze_set = set(rct_idx).intersection(set(nuc_idx_set).intersection(set(elec_idx_set)))
idx_to_analyze = \
    [idx for idx in rct_idx if idx in idx_to_analyze_set] \
     + [idx for idx in nuc_idx if idx.split('_')[0] in idx_to_analyze_set] \
     + [idx for idx in elec_idx if idx.split('_')[0] in idx_to_analyze_set]

# idx_to_analyze = rct_idx + nuc_idx + elec_idx

with tarfile.open('./orca_optimized_confs.tar.gz', 'w:gz') as tar:
    for idx in idx_to_analyze:
        path = os.path.join(out_dir, str(idx) + '.sdf')
        tar.add(path, arcname=os.path.basename(path))

# %%
import sys

src_dir = os.path.abspath('../../src')
if src_dir not in sys.path:
    sys.path.append(src_dir)

from glob import glob
from core_modules.molecule_formats import convert_xyz_to_sdf
from rdkit import Chem
from rdkit.Chem import AllChem


path_all = glob(out_dir + '/*.sdf')
path_err = [p for p in path_all if not any([p.split('/')[-1].split('.')[0] in idx_to_analyze])]
mols_err = [convert_xyz_to_sdf(p) for p in path_err]

ref_dir = './confs_for_gaussian_input'
ref_path_err = [p.replace(out_dir, ref_dir) for p in path_err]
ref_mols_err = [convert_xyz_to_sdf(p) for p in ref_path_err]

os.makedirs('./confs_err', exist_ok=True)

for ref_mol, mol, p in zip(ref_mols_err, mols_err, path_err):
    ref_mol.SetProp('_Name','optimized_by_xTB')
    mol.SetProp('_Name','optimized_by_Orca')
    
    # Create subdirectory for each molecule
    basename = os.path.basename(p).replace('.sdf', '')
    output_dir = os.path.join('./confs_err', basename)
    os.makedirs(output_dir, exist_ok=True)
    
    # Align mol to ref_mol
    try:
        AllChem.AlignMol(mol, ref_mol)
    except:
        print(f"Warning: Failed to align {basename}")
    
    # Write molecules to separate SDF files in subdirectory
    ref_writer = Chem.SDWriter(os.path.join(output_dir, 'optimized_by_xTB.sdf'))
    ref_writer.write(ref_mol)
    ref_writer.close()
    
    mol_writer = Chem.SDWriter(os.path.join(output_dir, 'optimized_by_Orca.sdf'))
    mol_writer.write(mol)
    mol_writer.close()
# Out:
# Warning: Failed to align 6900a5bc46d7cf94011cab6dce00577d_nuc_1
# !!! Warning !!! Distance between atoms 44 and 24 (0.998269 A) is suspicious.

# %% [markdown]
# # Case study:
# ## A test set of 100 reaction mechanisms where the reacting function groups are similar to the functional groups in the training data of MCA* and MAA*
#
# From [ReactivitiesDatasets in ChemDB](https://cdb.ics.uci.edu/cgibin/ReactivitiesDatasetsWeb.html)

# %%
# # Download file
# !mkdir -p ./100_rxn_mechanisms
# !wget -O ./100_rxn_mechanisms/100_rxn_mechanisms.csv https://cdb.ics.uci.edu/cgibin/dataset-reactivities/100_rxn_mechanisms.csv
# Out:
# --2026-02-14 15:05:47--  https://cdb.ics.uci.edu/cgibin/dataset-reactivities/100_rxn_mechanisms.csv
# Resolving cdb.ics.uci.edu (cdb.ics.uci.edu)... 128.195.8.93
# Connecting to cdb.ics.uci.edu (cdb.ics.uci.edu)|128.195.8.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27669 (27K) [text/csv]
# Saving to: ‘100_rxn_mechanisms.csv’
#
# 100_rxn_mechanisms. 100%[===================>]  27.02K  --.-KB/s    in 0.1s
#
# 2026-02-14 15:05:48 (229 KB/s) - ‘100_rxn_mechanisms.csv’ saved [27669/27669]

# %%
# # Import modules for analysis
# # See: https://deeprxn.ics.uci.edu/pmechdb/howtouse

# from __future__ import annotations

# from dataclasses import dataclass
# from typing import List, Optional, Tuple
# import pandas as pd


# @dataclass(frozen=True)
# class ArrowCode:
#     src: Tuple[int, ...]  # (a,) for atom a, (a,b) for bond a-b
#     dst: Tuple[int, ...]  # (a,) for atom a, (a,b) for bond a-b

#     def __repr__(self):
#         return f'({"=".join([str(i) for i in self.src])})->({"=".join([str(i) for i in self.dst])})'


# def split_record(record: str) -> Tuple[str, Optional[str]]:
#     """
#     Split a record into (reaction_smirks, arrow_codes).
#     Assumes arrow codes, if present, appear as the last whitespace-separated token.
#     """
#     s = record.strip()
#     parts = s.rsplit(None, 1)
#     if len(parts) == 2 and ('=' in parts[1] or ';' in parts[1]):
#         return parts[0], parts[1]
#     return s, None


# def parse_arrow_codes(arrow_codes: str) -> List[ArrowCode]:
#     """
#     Parse PMechDB arrow codes.
#     Example: "10=20;20,21=21"
#     """
#     arrows: List[ArrowCode] = []
#     for chunk in arrow_codes.split(';'):
#         chunk = chunk.strip()
#         if not chunk:
#             continue
#         if '=' not in chunk:
#             raise ValueError(f'Invalid arrow code (missing "="): {chunk}')
#         left, right = chunk.split('=', 1)
#         src = tuple(int(x) for x in left.split(',') if x)
#         dst = tuple(int(x) for x in right.split(',') if x)
#         if not src or not dst:
#             raise ValueError(f'Invalid arrow code site: {chunk}')
#         arrows.append(ArrowCode(src=src, dst=dst))
#     return arrows


# def humanize_arrows(arrows: List[ArrowCode]) -> List[str]:
#     """
#     Convert arrow codes to human-readable descriptions.
#     """
#     out = {
#         'bond_form': [],
#         'pi_to_atom': [],
#         'atom_to_pi': [],
#         'unknown': [],
#         }
#     for a in arrows:
#         if len(a.src) == 1 and len(a.dst) == 1:
#             out['bond_form'] = out['bond_form'] + [a]
#         elif len(a.src) == 2 and len(a.dst) == 1:
#             out['pi_to_atom'] = out['pi_to_atom'] + [a]
#         elif len(a.src) == 1 and len(a.dst) == 2:
#             out['atom_to_pi'] = out['atom_to_pi'] + [a]
#         else:
#             out['unknown'] = out['unknown'] + [a]
#     return out


# def explain_record(record: str):
#     _, arrow_codes = split_record(record)
#     if arrow_codes is not None:
#         arrows = parse_arrow_codes(arrow_codes)
#         return humanize_arrows(arrows)
#     return


# def extract_source_and_sink(record: str) -> pd.Series:
#     bond_form = explain_record(record)['bond_form']
#     src_snk = {
#         'source': [],
#         'sink': [],
#         }
#     for bf in bond_form:
#         src_snk['source'] = src_snk['source'] + [bf.src[0]]
#         src_snk['sink'] = src_snk['sink'] + [bf.dst[0]]
#     return pd.Series({key: val[0] if len(val) == 1 else tuple(val) for key, val in src_snk.items()})

# if __name__ == '__main__':
#     rec = 'CC[Si](CC)(CC)OCC#[C-:10].CC(C)(C=C)C([CH:20]=[O:21])OCC1=CC=CC=C1>>CC[Si](CC)(CC)OCC#[C:10][CH:20](C(C(C)(C)C=C)OCC1=CC=CC=C1)[O-:21] 10=20;20,21=21'
#     print(extract_source_and_sink(rec))
# Out:
# source    10
# sink      20
# dtype: int64

# %%
# from charset_normalizer import from_path
# import pandas as pd
# from rdkit import Chem

# best = from_path("100_rxn_mechanisms.csv").best()
# df = pd.read_csv("100_rxn_mechanisms.csv", encoding=best.encoding)

# df[['source','sink']] = df['SMIRKS'].apply(extract_source_and_sink)
# df_no_error = df[(df['source'].apply(lambda val: isinstance(val, int))) & (df['sink'].apply(lambda val: isinstance(val, int)))]

# uniq_reacs = {}

# for idx, smirks in df_no_error['SMIRKS'].items():
#     assert '>>' in smirks
#     for num, reac in enumerate(smirks.split('>>')[0].split('.')):
#         uniq_reacs[f'{idx}_{num}'] = reac

# uniq_reacs_df = pd.DataFrame.from_dict(uniq_reacs,orient='index',columns=['reactant_smi'])
# uniq_reacs_df['rxn_id'] = [idx.split('_')[0] for idx in uniq_reacs_df.index]
# uniq_reacs_df['mapped_atoms'] = uniq_reacs_df['reactant_smi'].apply(lambda smi: {atom.GetAtomMapNum(): atom.GetIdx() for atom in Chem.MolFromSmiles(smi).GetAtoms() if atom.GetAtomMapNum()})
# uniq_reacs_df['reactant_id_no_underbar'] = [idx.split('_')[0] for idx in uniq_reacs_df.index]

# print('Reactions with exactly one pair of electron source and sink:')
# display(df_no_error)
# print()

# print('Unique reactants:')
# display(uniq_reacs_df)

# df_no_error.to_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error.csv')
# uniq_reacs_df.to_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants.csv')
# Out:
# Reactions with exactly one pair of electron source and sink:
#                                                SMIRKS       Source type  \
# 0   CC1=CC=C(C=C1)[OH:10].C1=CC=C(C=C1)[C+:20](C2=...          O phenol
# 1   C[C+:20](C)CC(C)(C)C1=C(C=CC(=C1)Br)[OH:10]>>C...          O phenol
# 2   N#N.CC(C)=[O:10].[CH2+:20]C1=CC=CC=C1>>CC([CH3...        O=C ketone
# 3   C1C[O:10]C1.C1=CC=C(C=C1)[CH+:20]C2=CC=CC=C2>>...           O ether
# 4   CC1=CCC(CC1)[C+:20](C)C.CC1(C2CC1C3(C(C2)[O:10...           O ether
# ..                                                ...               ...
# 95  COC(=O)C1(CCCCC[C:20]1=[O:21])C2=CC=CC=[C-:10]...  C- carbanion sp2
# 96  COC1=CC(=[C-:10]C=C1)OC.CO[C:20](=[O:21])C1=CC...  C- carbanion sp2
# 97  CC(C)(C)/[N:21]=[CH:20]/C1=CC=CC=C1.[CH2-:10]C...  C- carbanion sp3
# 98  COC1=CC=C(C=C1)COCC[CH:20]=[O:21].[CH2-:10]CC=...  C- carbanion sp3
# 99  CC[Si](CC)(CC)OCC#[C-:10].CC(C)(C=C)C([CH:20]=...   C- carbanion sp
#
#        Sink type                                                Ref source  \
# 0   C+ carbenium  Schorigin; Makarow-Semljanski[Chemische Berich...     10
# 1   C+ carbenium  Vasudevan; Jayasree, Johnson; Alan T., Huang; ...     10
# 2   C+ carbenium  Fenhong Song, Ron W. Darbeau, Emil H. White J....     10
# 3   C+ carbenium  Kirmse, Wolfgang; Lelgemann, Rudolf; Friedrich...     10
# 4   C+ carbenium  E. R. Ruckel , R. T. Wojcik & H. G. Arlt Jr. (...     10
# ..           ...                                                ...    ...
# 95    C=O ketone  Tambar, Uttam K.; Stoltz, Brian M. J. Am. Chem...     10
# 96     C=O ester  Louisiana State University WO2008/11508, 2008,...     10
# 97     C=N imine  Yamashita, Yasuhiro; Suzuki, Hirotsugu; Sato, ...     10
# 98  C=O aldehyde  Masaki Ohta, Shota Kato, Tomoya Sugai, and Har...     10
# 99  C=O aldehyde  Gregson, Thomas; Thomas, Eric J. Tetrahedron, ...     10
#
#    sink
# 0    20
# 1    20
# 2    20
# 3    20
# 4    20
# ..  ...
# 95   20
# 96   20
# 97   20
# 98   20
# 99   20
#
# [99 rows x 6 columns]
# Unique reactants:
#                                       reactant_smi rxn_id      mapped_atoms
# 0_0                          CC1=CC=C(C=C1)[OH:10]      0           {10: 7}
# 0_1   C1=CC=C(C=C1)[C+:20](C2=CC=CC=C2)C3=CC=CC=C3      0           {20: 6}
# 1_0    C[C+:20](C)CC(C)(C)C1=C(C=CC(=C1)Br)[OH:10]      1   {20: 1, 10: 14}
# 2_0                                            N#N      2                {}
# 2_1                                   CC(C)=[O:10]      2           {10: 3}
# ...                                            ...    ...               ...
# 97_1                          [CH2-:10]C1=CC=CC=C1     97           {10: 0}
# 98_0             COC1=CC=C(C=C1)COCC[CH:20]=[O:21]     98  {20: 12, 21: 13}
# 98_1                                 [CH2-:10]CC=C     98           {10: 0}
# 99_0                     CC[Si](CC)(CC)OCC#[C-:10]     99          {10: 10}
# 99_1      CC(C)(C=C)C([CH:20]=[O:21])OCC1=CC=CC=C1     99    {20: 6, 21: 7}
#
# [190 rows x 3 columns]

# %%
# df_error = df[(~df['source'].apply(lambda val: isinstance(val, int))) | (~df['sink'].apply(lambda val: isinstance(val, int)))]
# display(df_error)
# Out:
#                                                SMIRKS  \
# 57  COC1=CC=C(C=C1)[CH:11]=[C:10]=[N-].C1CC[C:20](...
#
#                 Source type   Sink type  \
# 57  CCN- acetonitrile anion  C=O ketone
#
#                                                   Ref source sink
# 57  UNICHEM LABORATORIES LIMITEDWO2007/94008, 2007...     ()   ()

# %%
# print(df_error.SMIRKS.iloc[0])
# print(explain_record(df_error.SMIRKS.iloc[0]))
# Out:
# COC1=CC=C(C=C1)[CH:11]=[C:10]=[N-].C1CC[C:20](=[O:21])CC1>>COC1=CC=C(C=C1)[CH+:11][C:10](=[N-])[C:20]2(CCCCC2)[O-:21] 10,11=10,20;20,21=21
# {'bond_form': [], 'pi_to_atom': [(20=21)->(21)], 'atom_to_pi': [], 'unknown': [(10=11)->(10=20)]}

# %% [markdown]
# ### Reference calculation
#
# #### 1. ESNUEL (xTB -> Orca)

# %%
# # First you need to clone repository in this directory
# # NOTE: IF YOUR CONDA BASE DOES NOT LOCATE ON `${HOME}/miniconda3`, 
# #       PLEASE MODIFY `~/miniconda3/bin/activate` TO `YOUR_CONDA_BASE/bin/activate` IN LINE 3.
# !cd reference_calculation; git clone https://github.com/jensengroup/ESNUEL.git
# !cd reference_calculation/ESNUEL; conda env create -f environment.yml
# !~/miniconda3/bin/activate esnuel; conda install -n esnuel -c conda-forge openmpi setuptools=81.0.0 -y
# !cd reference_calculation; cp run_orca.py ESNUEL/src/esnuel/

# %% [markdown]
# After cloning, you need to download [xTB-6.5.1](https://github.com/grimme-lab/xtb/releases) and [ORCA-5.0.1](https://sites.google.com/site/orcainputlibrary/setting-up-orca) in `./reference_calculation/ESNUEL` directory **manually**.
#
# For more details, please refer [README in ESNUEL repository](https://github.com/jensengroup/ESNUEL).

# %%
# # Now it's time to start calculation!
# !~/miniconda3/envs/esnuel/bin/python reference_calculation/esnuel_calculator.py \
#     -b ./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants.csv \
#     -a ./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_calculated.txt \
#     -c reactant_smi \
#     -i reactant_id_no_underbar \
#     --parallel_calcs 9 \
#     --cpus_per_calc 5

# %% [markdown]
# Parse results after calculation

# %%
# import ast
# import pandas as pd

# def literal_eval(c):
#     try:
#         return ast.literal_eval(c)
#     except:
#         return c

# smis = pd.read_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_calculated.txt',index_col=0).drop_duplicates(subset=['reactant_smi']).set_index('reactant_smi',drop=True).applymap(literal_eval).to_dict(orient='index')

# def concatenate_mca_maa(df: pd.DataFrame, smi_col='smiles_SMI'):
#     elec_rows = []
#     nuc_rows = []
#     for _, row in df.iterrows():
#         smi = row[smi_col]
#         di = smis[smi]
#         for t in ['mca','maa']:
#             n = 'nuc' if t=='mca' else 'elec'
#             if f'{t}_strings' not in di or not di[f'{t}_strings'] or str(di[f'{t}_strings']) == 'nan':
#                 continue
#             sites_df = pd.DataFrame.from_dict(di[f'{t}_strings'], orient='index').reset_index().rename(columns={'index': n + '_sites'})
#             sites_df[['reactant_error','product_error']] = sites_df['Error Log (Reactant, Product)'].apply(lambda l: pd.Series({'reactant_error': l.split(', ')[0], 'product_error': l.split(', ')[-1]}))
#             row_df = pd.DataFrame([row] * len(sites_df), index=range(len(sites_df)))
#             sites_df = pd.concat([row_df, sites_df.drop('Error Log (Reactant, Product)', axis=1)], axis=1)
#             if t == 'mca':
#                 nuc_rows.append(sites_df)
#             else:
#                 elec_rows.append(sites_df)

#     return pd.concat(nuc_rows).reset_index(drop=True), pd.concat(elec_rows).reset_index(drop=True)

# df = pd.read_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants.csv',index_col=0)
# nuc_df, elec_df = concatenate_mca_maa(df, 'reactant_smi')

# nuc_df.to_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_calculated_nuc.csv')
# elec_df.to_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_calculated_elec.csv')

# %% [markdown]
# #### 2. ESNUEL_ML (xTB -> XGBoost)

# %%
# # First you need to clone repository in this directory
# # NOTE: IF YOUR CONDA BASE DOES NOT LOCATE ON `${HOME}/miniconda3`, 
# #       PLEASE MODIFY `~/miniconda3/bin/activate` TO `YOUR_CONDA_BASE/bin/activate` IN LINE 3.
# !cd reference_calculation; git clone https://github.com/jensengroup/ESNUEL_ML.git
# !cd reference_calculation/ESNUEL_ML/etc; conda env create -f environment.yml
# !cd reference_calculation/ESNUEL_ML/; wget -O models.tar.xz https://sid.erda.dk/share_redirect/Ear6g6wl0G; tar xf models.tar.xz; mv models src/esnuelML/.
# !cd reference_calculation/ESNUEL_ML/; mkdir dep; cd dep; wget https://github.com/grimme-lab/xtb/releases/download/v6.7.0/xtb-6.7.0-linux-x86_64.tar.xz; tar -xvf ./xtb-6.7.0-linux-x86_64.tar.xz
# !cd reference_calculation; cp predictor_output_df.py ESNUEL_ML/src/esnuelML/

# %%
# # Now it's time to start prediction!
# !~/miniconda3/envs/esnuel/bin/python reference_calculation/esnuelML_predictor.py \
#     -b ./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants.csv \
#     -a ./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_predicted.txt \
#     -c reactant_smi \
#     -i reactant_id_no_underbar \
#     --parallel_calcs 20 \

# %% [markdown]
# Parse results after prediction

# %%
# import ast
# import pandas as pd

# def literal_eval(c):
#     try:
#         return ast.literal_eval(c)
#     except:
#         return c

# smis = pd.read_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_predicted.txt',index_col=0).drop_duplicates(subset=['reactant_smi']).set_index('reactant_smi',drop=True).applymap(literal_eval).to_dict(orient='index')

# def concatenate_mca_maa(df: pd.DataFrame, smi_col='smiles_SMI'):
#     elec_rows = []
#     nuc_rows = []
#     for _, row in df.iterrows():
#         smi = row[smi_col]
#         di = smis[smi]
#         for t in ['mca','maa']:
#             n = 'nuc' if t=='mca' else 'elec'
#             if f'{t}_strings' not in di or not di[f'{t}_strings'] or str(di[f'{t}_strings']) == 'nan':
#                 continue
#             sites_df = pd.DataFrame.from_dict(di[f'{t}_strings'], orient='index').reset_index().rename(columns={'index': n + '_sites'})
#             row_df = pd.DataFrame([row] * len(sites_df), index=range(len(sites_df)))
#             sites_df = pd.concat([row_df, sites_df.drop('Reactant', axis=1)], axis=1)
#             if t == 'mca':
#                 nuc_rows.append(sites_df)
#             else:
#                 elec_rows.append(sites_df)

#     return pd.concat(nuc_rows).reset_index(drop=True), pd.concat(elec_rows).reset_index(drop=True)

# df = pd.read_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants.csv',index_col=0)
# nuc_df, elec_df = concatenate_mca_maa(df, 'reactant_smi')

# nuc_df.to_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_predicted_nuc.csv')
# elec_df.to_csv('./100_rxn_mechanisms/100_rxn_mechanisms_no_error_reactants_predicted_elec.csv')
